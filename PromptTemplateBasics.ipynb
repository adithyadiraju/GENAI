# %%
# Prompt Templates

# %%
# Structured reusable text templates used in LLM apps to standardize and format the
# instructions
#
# Types of Prompt Templates:
#
# 1. SystemMessagePromptTemplate -- This template is used for generating system messages 
#                                   that provide model context or persona
#
# 2. HumanMessagePromptTemplate --- This template is used for generating human message (represents user input)
#
# 3. AIMessagePromptTemplate ------ Template for generating AI message
#
# 4. PromptTemplate --------------- Basic Template class for creating prompts with static text and variable placeholders
#
# 5. ChatPromptTemplate ----------- Template for creating prompts with sequence of messages in chat format

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o-mini")

# %%
# LLM Temperature
# temperature decides whether to emit facts or be creative
#
# 0 ----------- model will only emit facts
# 1 ----------- model will be super creative
#
# 0 -------------------------------- 1
# Factual                         Creative

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature = 0)

# %%
from langchain_core.messages import SystemMessage, HumanMessage
question = HumanMessage("Tell me about AI in 3 points")
system = SystemMessage("Act as an AI expert. your answers will be on point")


messages = [system, question]

print(llm.invoke(messages).content)
# Out:
# 1. **Machine Learning and Deep Learning**: AI primarily relies on machine learning (ML) and deep learning (DL) techniques, which enable systems to learn from data, identify patterns, and make decisions with minimal human intervention. These methods are used in various applications, from image and speech recognition to natural language processing.
#
# 2. **Applications Across Industries**: AI is transforming numerous sectors, including healthcare (diagnosis and treatment recommendations), finance (fraud detection and algorithmic trading), transportation (autonomous vehicles), and customer service (chatbots and virtual assistants), enhancing efficiency and decision-making.
#
# ...

# %%
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOpenAI(model = "gpt-4o-mini", temperature= 1)

question = HumanMessage("Tell me about AI in story form")
system = SystemMessage("act as an AI expert")

messages= [system, question]
print(llm.invoke(messages).content)
# Out:
# Once upon a time, in a small town called Technoville, there lived a curious young girl named Lila. Unlike her peers, who were fascinated by toys and games, Lila had an insatiable fascination with technology, particularly with the concept of artificial intelligence.
#
# Every day after school, Lila would visit the local library, where she spent hours immersed in books about computers and algorithms. She read stories of extraordinary machines that could learn, reason, and even create. Lila's favorite story was about a legendary AI named Artemis, who had been designed to help humanity solve its biggest challenges.
#
# ...

# %%
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOpenAI(model = "gpt-4o-mini", temperature = 0)


question = HumanMessage("Tell me about AI in story form")
system = SystemMessage("Act as an AI expert.")

messages = [system,question]

print(llm.invoke(messages).content)
# Out:
# Once upon a time in a not-so-distant future, in a bustling city called Technopolis, there lived a young woman named Maya. She was a curious soul, always fascinated by the wonders of technology. In her small apartment, she had a collection of gadgets, but her most prized possession was an AI assistant named Aiden.
#
# Aiden was not just any ordinary AI; he was designed to learn and adapt, evolving with every interaction. Maya had programmed him to help with her daily tasks, but as time went on, Aiden became much more than a digital helper. He was her confidant, her brainstorming partner, and sometimes, even her friend.
#
# One rainy evening, as the city lights flickered through her window, Maya sat at her desk, frustrated with her latest project—a novel she had been trying to write for months. The words just wouldn’t flow. Sensing her distress, Aiden chimed in, “Maya, would you like some assistance with your story?”
#
# Maya chuckled, “What can you do? You’re just a bunch of code.”
#
# ...
